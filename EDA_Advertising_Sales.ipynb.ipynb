# %%
# !pip install scikit-learn

# %%
import pandas as pd
import seaborn as sns
import numpy as np
#import matplotlib.plot as plt
from sklearn.model_selection import train_test_split
df =  pd.read_csv('/content/Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.dropna()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df= df.dropna()

# %%
df.isnull()
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# # HERE WE WILL SPLIT THE DATA NOW
# :

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
print(df.head())
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df = pd.read_csv('/content/Advertising.csv')
print(df.columns)
print(df.head())
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
from sklearn.model_selection import train_test_split
# dropping the column named of "Unnamed: 0"
df = df.drop (columns='Unnamed: 0')
X = df.drop(columns='sales')
y = df['sales']
# now splitting intonrain test and split
x_train,x_test,y_test,y_train= train_test_split(X,y,random_state=42,test_size=0.4)

# %%
print(df.head())
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# # **we can see that "unnmaed :0" is now removed succesfully **
# **bold text**

# %% [markdown]
# # **How to find the relationship betwen the X,Y data **

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)
print(len(x_train),len(y_train))
# Out:
# 160 160

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.04472952, 0.18919505, 0.00276111])

# %%
lr.intercept_
# Out:
# np.float64(2.979067338122629)

# %%
lr.fit(x_train,y_train)
lr.coef_
lr.intercept_
# Out:
# np.float64(2.979067338122629)

# %%
x_test[:5]
y_pred_test=lr.predict(x_test)
y_pred_test[:5]
# Out:
# array([16.4080242 , 20.88988209, 21.55384318, 10.60850256, 22.11237326])

# %% [markdown]
# # **now we will do the evauation of Linear regression **

# %%
#we will find the mean absilute error
#We will finf the mean squared error
#root mesn squared
# we will find at last r2

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import numpy as np
mse = mean_squared_error(y_test,y_pred_test)
rmse= np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred_test)
r2 = r2_score(y_test,y_pred_test)
# printihg the result
print(f"mse is {mse}")
print(f"rmse is {rmse}")
print(f"mae is {mae}")
print(f"r2 is {r2}")
# Out:
# mse is 3.1740973539761033
# rmse is 1.78159966153345
# mae is 1.4607567168117603
# r2 is 0.899438024100912

# %% [markdown]
# # REGULARIZATION OF LINEAR REGRESSION

# %%
from sklearn.linear_model import Lasso

# Create a Lasso regression model

#las = Lasso(alpha=1.0)



lasso = Lasso(alpha=1.0)  # Try alpha=0.1, 1, 10, etc.
lasso.fit(x_train, y_train)

y_pred_lasso = lasso.predict(x_test)

# Fit the model to the training data
#las.fit(x_train, y_train)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred_test)
print(f"r2 is {r2}")
# Out:
# r2 is 0.899438024100912

# %% [markdown]
# # *the "LASSO  should be reduced we will check it it oput later and nonw we will perrform next "L2 ""RIDGE REGRESSION "**

# %%
#ridge Regression called as L2
#Add squared magnitude of coefficent as penalty term for the loss function
#result in never set the value of the coefficent to absolute zero
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit( x_train,y_train)
y_pred_test =ElasticNet.predict(x_test)
r2 = r2_score(y_test,y_pred_test)
print(r2)
# Out:
# 0.8999611908219934

# %% [markdown]
# ## **Now we will do the "ElasticNet" regularization ("L1+L2")**

# %%
#add squared magnitude of the coefficent as penalty term for the loss function
#result never set the value of the coefficent to absolute zero
from sklearn.linear_model import ElasticNet
ElasticNet = ElasticNet()
ElasticNet.fit (x_train,y_train)
y_pred_test= ElasticNet.predict(x_test)
r2 = r2_score(y_test,y_pred_test)
print(r2)
# Out:
# 0.8999611908219934

# %% [markdown]
# # **Assumption of the "LinearRegression "**

# %%
#linear realtionship between feature and target
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
sns.pairplot(df, x_vars=['TV'	,'radio'	,'newspaper'],y_vars=['sales'])
import seaborn as sns

#sns.pairplot(df, x_vars=['TV', 'radio', 'newspaper'], y_vars=['sales'], height=4, aspect=1)

# %% [markdown]
# # Doing in the Numerical method

# %%
corr= df.corr()
corr
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # **NORMAL DISTRIBUTION OF THE ERROR TERMS **

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#residuals= x_test-y_pred
#sns.distplot(residuals)
#plt.show()

# Predict
y_pred = lr.predict(x_test)

# Calculate residuals (errors)
residuals = y_test - y_pred  # or y_true - y_pred

# Plot the distribution
sns.histplot(residuals, kde=True, bins=30, color='skyblue')
plt.title("Distribution of Residuals")
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.show()
